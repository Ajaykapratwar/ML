# %%
import matplotlib.pyplot as plt
from sklearn.cluster import DBSCAN
# %matplotlib inline

# %%
from sklearn.datasets import make_circles

# %%
X, y = make_circles(n_samples=800, factor=0.3, noise=0.1)

# %%
X
# Out:
# array([[ 0.67704354,  0.49157381],
#        [ 0.03726681, -0.27605974],
#        [-1.07046039,  0.17734519],
#        ...,
#        [-0.17828171,  0.3992942 ],
#        [-0.318143  ,  0.33588272],
#        [ 0.91109748,  0.14648355]])

# %%
plt.scatter(X[:,0], X[:,1], c=y)
plt.show()

# %%
from sklearn.cluster import DBSCAN

# %%
dbscan = DBSCAN(eps=0.10)

# %%
prediction = dbscan.fit_predict(X)

# %%
index = (prediction < 0)

# %%
plt.scatter(X[:,0], X[:,1], c=y)
plt.scatter(X[index,0], X[index,1], edgecolors='r')
plt.show()
